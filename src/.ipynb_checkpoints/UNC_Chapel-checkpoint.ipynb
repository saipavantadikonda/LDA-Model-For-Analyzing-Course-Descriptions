# %%
from bs4 import BeautifulSoup

# %%
import requests
import re
import pandas as pd

# %%
base_url = "https://catalog.unc.edu/courses/"
result2 = requests.get(base_url)
doc2 = BeautifulSoup(result2.text, "html.parser")
description1 = doc2.find_all("li", attrs={"class","active self isparent"})
data1,data2 = [],[]

for i in range(len(description1)):
    q = description1[i].find_all("li")

        #data1.append(description1[i].find_all("li"))
for j in range(len(q)):
    data1.append(q[j].a.text)
for k in data1:
    data2.append(re.findall(r"\((.*?)\)", k)[-1])
data2
# Out:
# ['AERO',
#  'AAAD',
#  'AMST',
#  'ANTH',
#  'APPL',
#  'ARAB',
#  'ARCH',
#  'ARMY',
#  'ARTH',
#  'ASIA',
#  'ASTR',
#  'BIOC',
#  'BCB',
#  'BBSP',
#  'BIOL',
#  'BMME',
#  'BIOS',
#  'BCS',
#  'BUSI',
#  'CHIP',
#  'CATA',
#  'CBPH',
#  'CBIO',
#  'CBMC',
#  'CHEM',
#  'CHER',
#  'CHWA',
#  'CHIN',
#  'PLAN',
#  'CLAR',
#  'CLAS',
#  'CLSC',
#  'CRMH',
#  'COMM',
#  'CMPL',
#  'COMP',
#  'EURO',
#  'CZCH',
#  'DENG',
#  'DHYG',
#  'DHED',
#  'DRAM',
#  'DTCH',
#  'ECON',
#  'EDUC',
#  'ENDO',
#  'ENGL',
#  'ENEC',
#  'ENVR',
#  'EPID',
#  'EXSS',
#  'EDMX',
#  'SPCL',
#  'DPET',
#  'FOLK',
#  'FREN',
#  'GNET',
#  'GEOG',
#  'GEOL',
#  'GERM',
#  'GSLL',
#  'GLBL',
#  'GOVT',
#  'GRAD',
#  'GREK',
#  'HBEH',
#  'HPM',
#  'HEBR',
#  'HNUR',
#  'HIST',
#  'HUNG',
#  'INLS',
#  'IDST',
#  'ITAL',
#  'JAPN',
#  'JWST',
#  'KOR',
#  'LATN',
#  'LTAM',
#  'LFIT',
#  'LGLA',
#  'LING',
#  'MACD',
#  'MNGT',
#  'MASC',
#  'MTSC',
#  'MHCH',
#  'MATH',
#  'MEJO',
#  'MCRO',
#  'MUSC',
#  'NAVS',
#  'NBIO',
#  'NSCI',
#  'NURS',
#  'NUTR',
#  'OCSC',
#  'OCCT',
#  'OPER',
#  'ORPA',
#  'ORAD',
#  'ORTH',
#  'PATH',
#  'PWAD',
#  'PEDO',
#  'PERI',
#  'PRSN',
#  'PHRS',
#  'DPMP',
#  'PHCO',
#  'PHCY',
#  'DPOP',
#  'DPPE',
#  'PHIL',
#  'PHYA',
#  'PHYS',
#  'PHYI',
#  'PLSH',
#  'POLI',
#  'PORT',
#  'PACE',
#  'PROS',
#  'PSYC',
#  'PUBA',
#  'PUBH',
#  'PLCY',
#  'RADI',
#  'RECR',
#  'RELI',
#  'ROML',
#  'RUSS',
#  'SPHG',
#  'SLAV',
#  'SOWO',
#  'SOCI',
#  'SPAN',
#  'SPHS',
#  'STOR',
#  'ARTS',
#  'SWAH',
#  'TOXC',
#  'TURK',
#  'UKRN',
#  'VIET',
#  'WGST',
#  'WOLO',
#  'MAYA']

# %%
def extraction():
        data =[]
        data_1 = []
        data_2 =[]
        data_3 =[]
        
        for i1 in data2:
            result = requests.get(base_url+ i1.lower())
            print(result)
            doc = BeautifulSoup(result.text, "html.parser")
            description = doc.find_all("div", attrs={"class","courseblock"})
            
            for i in range(len(description)):
                s = (description[i].find("strong").text)
                data0=s.split(".")
                data.append(data0[0])
                data_1.append(data0[1])
        
                h= ((description[i].find_all("p")))
                data_2.append(h[1].text.replace("\n",""))
                data_3.append(i1)
                #data1 = h[1].split("\n")
                #for h1 in h[1]:
                   # data_1.append(h1.text)
           
        return data,data_1,data_2,data_3

            
courses = extraction()
courses_df = pd.DataFrame({'CourseNumber':courses[0], 'CourseTitle':courses[1], 'Description':courses[2], 'CourseDepartment':courses[3]})
courses_df.to_csv('../data/chapel.csv', sep = '\xa0')
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
#base_url = "https://catalog.unc.edu/courses/"
#result2 = requests.get(base_url)
#doc2 = BeautifulSoup(result2.text, "html.parser")
#description1 = doc2.find_all("li", attrs={"class","active self isparent"})
#data1,data2 = [],[]

#for i in range(len(description1)):
    #q = description1[i].find_all("li")

        #data1.append(description1[i].find_all("li"))
#for j in range(len(q)):
    #data1.append(q[j].a.text)
#print(data1)
#for k in data1:
    #if (k == 'PHARMACY  (NON-\u200bDEPARTMENTAL) (PHCY)'):
        #data2.append(re.findall(r"\((.*?)\)", k)[1])
    #else:
        #data2.append(re.search(r"\((.*?)\)", k).group(1))
#data2

# %%
#"hello. sam. gee".split('.')

# %%
len(courses_df)
# Out:
# 9721

# %%
courses_df
# Out:
#      CourseNumber                                        CourseTitle  \
# 0        AERO 101    Heritage and Values of the United States Air...
# 1        AERO 102    Heritage and Values of the United States Air...
# 2        AERO 190                                            Seminar
# 3        AERO 196                                  Independent Study
# 4        AERO 201         Team and Air Force Leadership Fundamentals
# ...           ...                                                ...
# 9716     WOLO 403                             Intermediate Wolof III
# 9717     WOLO 404                              Intermediate Wolof IV
# 9718     WOLO 405                                   Advanced Wolof V
# 9719     WOLO 406                                  Advanced Wolof VI
# 9720     MAYA 401                       Introduction to Yucatec Maya
#
#                                             Description CourseDepartment
# 0     Part one of a two-part course that examines th...             AERO
# 1     Part two of a two-part course that examines th...             AERO
# 2     Seminar in topics related to the United States...             AERO
# 3     Readings and research of topics regarding the ...             AERO
# 4     This course lays the foundation for leading ef...             AERO
# ...                                                 ...              ...
# 9716   WOL 403 is appropriate for learners who have ...             WOLO
# 9717   WOL 404 is appropriate for learners who have ...             WOLO
# 9718   This course is intended for learners who have...             WOLO
# 9719   This course is intended for learners who have...             WOLO
# 9720  Introduction to basic grammar and vocabulary, ...             MAYA
#
# [9721 rows x 4 columns]

# %%
dept1 = []
for y in data1:
        dept1.append(re.sub("[\(\[].*?[\)\]]", "", y))
print(len(dept1))
dept1
# Out:
# 147
# ['AEROSPACE STUDIES ',
#  'AFRICAN, AFRICAN-\u200bAMERICAN, DIASPORA STUDIES ',
#  'AMERICAN STUDIES ',
#  'ANTHROPOLOGY ',
#  'APPLIED SCIENCES ',
#  'ARABIC ',
#  'ARCHAEOLOGY ',
#  'ARMY ',
#  'ART HISTORY ',
#  'ASIAN STUDIES ',
#  'ASTRONOMY ',
#  'BIOCHEMISTRY ',
#  'BIOINFORMATICS AND COMPUTATIONAL BIOLOGY ',
#  'BIOLOGICAL AND BIOMEDICAL SCIENCES ',
#  'BIOLOGY ',
#  'BIOMEDICAL ENGINEERING ',
#  'BIOSTATISTICS ',
#  'BOSNIAN-\u200bCROATIAN-\u200bSERBIAN ',
#  'BUSINESS ADMINISTRATION ',
#  'CAROLINA HEALTH INFORMATICS PROGRAM ',
#  'CATALAN ',
#  'CELL BIOLOGY AND PHYSIOLOGY ',
#  'CELL AND DEVELOPMENT BIOLOGY ',
#  'CHEMICAL BIOLOGY AND MEDICINAL CHEMISTRY ',
#  'CHEMISTRY ',
#  'CHEROKEE ',
#  'CHICHEWA ',
#  'CHINESE ',
#  'CITY AND REGIONAL PLANNING ',
#  'CLASSICAL ARCHAEOLOGY ',
#  'CLASSICS ',
#  'CLINICAL LABORATORY SCIENCE ',
#  'CLINICAL REHABILITATION AND MENTAL HEALTH COUNSEL ',
#  'COMMUNICATION STUDIES ',
#  'COMPARATIVE LITERATURE ',
#  'COMPUTER SCIENCE ',
#  'CONTEMPORARY EUROPEAN STUDIES ',
#  'CZECH ',
#  'DENTAL GRADUATE COURSE ',
#  'DENTAL HYGIENE ',
#  'DENTAL HYGIENE EDUCATION ',
#  'DRAMATIC ART ',
#  'DUTCH ',
#  'ECONOMICS ',
#  'EDUCATION ',
#  'ENDODONTICS ',
#  'ENGLISH ',
#  'ENVIRONMENT AND ECOLOGY ',
#  'ENVIRONMENT SCIENCES ',
#  'EPIDEMIOLOGY ',
#  'EXERCISE AND SPORT SCIENCE ',
#  'EXPERIENCED TEACHER EDUCATION ',
#  'EXPERIENTIAL AND SPECIAL STUDIES ',
#  'EXPERIMENTAL THERAPEUTICS ',
#  'FOLKLORE ',
#  'FRENCH ',
#  'GENETICS AND MOLECULAR BIOLOGY ',
#  'GEOGRAPHY ',
#  'GEOLOGICAL SCIENCES ',
#  'GERMAN ',
#  'GERMANIC AND SLAVIC LANGUAGES AND LITERATURES ',
#  'GLOBAL STUDIES ',
#  'GOVERNMENT ',
#  'GRADUATE STUDIES ',
#  'GREEK ',
#  'HEALTH BEHAVIOR ',
#  'HEALTH POLICY AND MANAGEMENT ',
#  'HEBREW ',
#  'HINDI-\u200bURDU ',
#  'HISTORY ',
#  'HUNGARIAN ',
#  'INFORMATION AND LIBRARY SCIENCE ',
#  'INTERDISCIPLINARY STUDIES ',
#  'ITALIAN ',
#  'JAPANESE ',
#  'JEWISH STUDIES ',
#  'KOREAN ',
#  'LATIN ',
#  'LATIN AMERICAN STUDIES ',
#  'LIFETIME FITNESS ',
#  'LINGALA LANGUAGE ',
#  'LINGUISTICS ',
#  'MACEDONIAN ',
#  'MANAGEMENT AND SOCIETY ',
#  'MARINE SCIENCE ',
#  'MATERIAL SCIENCE ',
#  'MATERNAL AND CHILD HEALTH ',
#  'MATHEMATICS ',
#  'MEDIA AND JOURNALISM ',
#  'MICROBIOLOGY ',
#  'MUSIC ',
#  'NAVAL SCIENCE ',
#  'NEUROBIOLOGY ',
#  'NEUROSCIENCE ',
#  'NURSING ',
#  'NUTRITION ',
#  'OCCUPATIONAL SCIENCE ',
#  'OCCUPATIONAL THERAPY ',
#  'OPERATIVE DENTISTRY ',
#  'ORAL PATHOLOGY ',
#  'ORAL RADIOLOGY ',
#  'ORTHODONTICS ',
#  'PATHOLOGY ',
#  'PEACE, WAR, AND DEFENSE ',
#  'PEDIATRIC DENTISTRY ',
#  'PERIODONTOLOGY ',
#  'PERSIAN ',
#  'PHARMACEUTICAL SCIENCES ',
#  'PHARMACOENGINEERING AND MOLECULAR PHARMACEUTICS ',
#  'PHARMACOLOGY ',
#  'PHARMACY   ',
#  'PHARMACY OUTCOMES AND POLICY ',
#  'PHARMACY PRACTICE AND EXPERIENTIAL EDUCATION ',
#  'PHILOSOPHY ',
#  'PHYSICAL ACTIVITIES ',
#  'PHYSICS ',
#  'PHYSIOLOGY ',
#  'POLISH ',
#  'POLITICAL SCIENCE ',
#  'PORTUGUESE ',
#  'PRACTICE ADVANCEMENT AND CLINICAL EDUCATION ',
#  'PROSTHODONTICS ',
#  'PSYCHOLOGY ',
#  'PUBLIC ADMINISTRATION ',
#  'PUBLIC HEALTH ',
#  'PUBLIC POLICY ',
#  'RADIOLOGIC SCIENCE ',
#  'RECREATION AND LEISURE STUDIES ',
#  'RELIGIOUS STUDIES ',
#  'ROMANCE LANGUAGES ',
#  'RUSSIAN ',
#  'SCHOOL OF PUBLIC HEALTH GENERAL ',
#  'SLAVIC LANGUAGES ',
#  'SOCIAL WORK ',
#  'SOCIOLOGY ',
#  'SPANISH ',
#  'SPEECH AND HEARING SCIENCES ',
#  'STATISTICS AND OPERATIONS RESEARCH ',
#  'STUDIO ART ',
#  'SWAHILI ',
#  'TOXICOLOGY ',
#  'TURKISH ',
#  'UKRAINIAN ',
#  'VIETNAMESE ',
#  "WOMEN'S AND GENDER STUDIES ",
#  'WOLOF LANGUAGE ',
#  'YUCATEC MAYA LANGUAGE ']

# %%
x1 = (courses_df.CourseDepartment.value_counts(sort=False))
xi2_1 = list(x1)
print(len(xi2_1))
xi2_1
# Out:
# 147
# [13,
#  95,
#  119,
#  267,
#  40,
#  23,
#  5,
#  12,
#  164,
#  144,
#  29,
#  63,
#  25,
#  7,
#  237,
#  63,
#  64,
#  8,
#  158,
#  7,
#  2,
#  20,
#  7,
#  5,
#  114,
#  5,
#  3,
#  39,
#  108,
#  50,
#  52,
#  48,
#  22,
#  212,
#  129,
#  131,
#  18,
#  10,
#  11,
#  44,
#  15,
#  141,
#  7,
#  153,
#  343,
#  4,
#  311,
#  127,
#  129,
#  81,
#  91,
#  45,
#  3,
#  34,
#  52,
#  98,
#  36,
#  136,
#  119,
#  113,
#  68,
#  46,
#  6,
#  19,
#  34,
#  82,
#  155,
#  6,
#  16,
#  389,
#  9,
#  149,
#  23,
#  54,
#  29,
#  55,
#  18,
#  53,
#  18,
#  23,
#  4,
#  99,
#  6,
#  16,
#  82,
#  34,
#  58,
#  123,
#  180,
#  24,
#  147,
#  14,
#  38,
#  38,
#  170,
#  61,
#  5,
#  26,
#  9,
#  7,
#  8,
#  13,
#  22,
#  107,
#  7,
#  11,
#  6,
#  16,
#  6,
#  50,
#  99,
#  15,
#  5,
#  168,
#  63,
#  113,
#  5,
#  10,
#  231,
#  48,
#  13,
#  9,
#  178,
#  57,
#  61,
#  105,
#  29,
#  13,
#  283,
#  42,
#  44,
#  17,
#  12,
#  103,
#  144,
#  117,
#  106,
#  109,
#  79,
#  9,
#  15,
#  5,
#  2,
#  2,
#  153,
#  6,
#  1]

# %%
lenlist1=[]
for i in range(len(dept1)):
    xi = int(xi2_1[i])
    while(xi!=0):
        lenlist1.append(dept1[i])
        xi = xi-1
        
lenlist1
p1 = pd.DataFrame(lenlist1)

# %%
p1
# Out:
#                            0
# 0         AEROSPACE STUDIES
# 1         AEROSPACE STUDIES
# 2         AEROSPACE STUDIES
# 3         AEROSPACE STUDIES
# 4         AEROSPACE STUDIES
# ...                      ...
# 9716         WOLOF LANGUAGE
# 9717         WOLOF LANGUAGE
# 9718         WOLOF LANGUAGE
# 9719         WOLOF LANGUAGE
# 9720  YUCATEC MAYA LANGUAGE
#
# [9721 rows x 1 columns]

# %%
courses_df['Department'] = lenlist1

# %%
courses_df
# Out:
#      CourseNumber                                        CourseTitle  \
# 0        AERO 101    Heritage and Values of the United States Air...
# 1        AERO 102    Heritage and Values of the United States Air...
# 2        AERO 190                                            Seminar
# 3        AERO 196                                  Independent Study
# 4        AERO 201         Team and Air Force Leadership Fundamentals
# ...           ...                                                ...
# 9716     WOLO 403                             Intermediate Wolof III
# 9717     WOLO 404                              Intermediate Wolof IV
# 9718     WOLO 405                                   Advanced Wolof V
# 9719     WOLO 406                                  Advanced Wolof VI
# 9720     MAYA 401                       Introduction to Yucatec Maya
#
#                                             Description CourseDepartment  \
# 0     Part one of a two-part course that examines th...             AERO
# 1     Part two of a two-part course that examines th...             AERO
# 2     Seminar in topics related to the United States...             AERO
# 3     Readings and research of topics regarding the ...             AERO
# 4     This course lays the foundation for leading ef...             AERO
# ...                                                 ...              ...
# 9716   WOL 403 is appropriate for learners who have ...             WOLO
# 9717   WOL 404 is appropriate for learners who have ...             WOLO
# 9718   This course is intended for learners who have...             WOLO
# 9719   This course is intended for learners who have...             WOLO
# 9720  Introduction to basic grammar and vocabulary, ...             MAYA
#
#                   Department
# 0         AEROSPACE STUDIES
# 1         AEROSPACE STUDIES
# 2         AEROSPACE STUDIES
# 3         AEROSPACE STUDIES
# 4         AEROSPACE STUDIES
# ...                      ...
# 9716         WOLOF LANGUAGE
# 9717         WOLOF LANGUAGE
# 9718         WOLOF LANGUAGE
# 9719         WOLOF LANGUAGE
# 9720  YUCATEC MAYA LANGUAGE
#
# [9721 rows x 5 columns]

# %%
courses_df = courses_df.drop(['CourseDepartment'],axis =1)
courses_df
# Out:
#      CourseNumber                                        CourseTitle  \
# 0        AERO 101    Heritage and Values of the United States Air...
# 1        AERO 102    Heritage and Values of the United States Air...
# 2        AERO 190                                            Seminar
# 3        AERO 196                                  Independent Study
# 4        AERO 201         Team and Air Force Leadership Fundamentals
# ...           ...                                                ...
# 9716     WOLO 403                             Intermediate Wolof III
# 9717     WOLO 404                              Intermediate Wolof IV
# 9718     WOLO 405                                   Advanced Wolof V
# 9719     WOLO 406                                  Advanced Wolof VI
# 9720     MAYA 401                       Introduction to Yucatec Maya
#
#                                             Description  \
# 0     Part one of a two-part course that examines th...
# 1     Part two of a two-part course that examines th...
# 2     Seminar in topics related to the United States...
# 3     Readings and research of topics regarding the ...
# 4     This course lays the foundation for leading ef...
# ...                                                 ...
# 9716   WOL 403 is appropriate for learners who have ...
# 9717   WOL 404 is appropriate for learners who have ...
# 9718   This course is intended for learners who have...
# 9719   This course is intended for learners who have...
# 9720  Introduction to basic grammar and vocabulary, ...
#
#                   Department
# 0         AEROSPACE STUDIES
# 1         AEROSPACE STUDIES
# 2         AEROSPACE STUDIES
# 3         AEROSPACE STUDIES
# 4         AEROSPACE STUDIES
# ...                      ...
# 9716         WOLOF LANGUAGE
# 9717         WOLOF LANGUAGE
# 9718         WOLOF LANGUAGE
# 9719         WOLOF LANGUAGE
# 9720  YUCATEC MAYA LANGUAGE
#
# [9721 rows x 4 columns]

# %%
courses_df.rename(columns={'Description':'CourseDescription','Department':'CourseDepartment'}, inplace = True)
courses_df
# Out:
#      CourseNumber                                        CourseTitle  \
# 0        AERO 101    Heritage and Values of the United States Air...
# 1        AERO 102    Heritage and Values of the United States Air...
# 2        AERO 190                                            Seminar
# 3        AERO 196                                  Independent Study
# 4        AERO 201         Team and Air Force Leadership Fundamentals
# ...           ...                                                ...
# 9716     WOLO 403                             Intermediate Wolof III
# 9717     WOLO 404                              Intermediate Wolof IV
# 9718     WOLO 405                                   Advanced Wolof V
# 9719     WOLO 406                                  Advanced Wolof VI
# 9720     MAYA 401                       Introduction to Yucatec Maya
#
#                                       CourseDescription  \
# 0     Part one of a two-part course that examines th...
# 1     Part two of a two-part course that examines th...
# 2     Seminar in topics related to the United States...
# 3     Readings and research of topics regarding the ...
# 4     This course lays the foundation for leading ef...
# ...                                                 ...
# 9716   WOL 403 is appropriate for learners who have ...
# 9717   WOL 404 is appropriate for learners who have ...
# 9718   This course is intended for learners who have...
# 9719   This course is intended for learners who have...
# 9720  Introduction to basic grammar and vocabulary, ...
#
#             CourseDepartment
# 0         AEROSPACE STUDIES
# 1         AEROSPACE STUDIES
# 2         AEROSPACE STUDIES
# 3         AEROSPACE STUDIES
# 4         AEROSPACE STUDIES
# ...                      ...
# 9716         WOLOF LANGUAGE
# 9717         WOLOF LANGUAGE
# 9718         WOLOF LANGUAGE
# 9719         WOLOF LANGUAGE
# 9720  YUCATEC MAYA LANGUAGE
#
# [9721 rows x 4 columns]

# %%
courses_df.to_csv('../data/chapel_temp1.csv', sep = '\xa0')

# %%
courses_df.isnull().sum()
# Out:
# CourseNumber         0
# CourseTitle          0
# CourseDescription    0
# CourseDepartment     0
# dtype: int64
