# %%
 from bs4 import BeautifulSoup, NavigableString, Tag

# %%
import pandas as pd
import re
import requests
import numpy as np

# %%
base_url = "https://catalogs.gsu.edu/content.php?catoid=4&catoid=4&navoid=351"

# %%
#def extraction():
   # data =[]
   # data_1 =[]
  #  data_2 =[]
   # for r in range(1,2):
       # query_parameter = "&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D="+str(r)+"#acalog_template_course_filter"
       # url = base_url + query_parameter
      #  result = requests.get(url)
        #print(result)
      #  doc = BeautifulSoup(result.text,"html.parser")
       # description = doc.find_all("td",attrs ={"class","width"})
      #  for i in range(len(description)):
              #  q =(description[i].find("a").text.replace("\xa0"," "))
              #  data0 = q.split("-",1)
              #  data.append(data0[0])
             #   data_1.append(data0[1])
                
        #len(data)
        #len(data_1)
        #doc1 = BeautifulSoup(result.text,"html.parser")
        #description1 = doc1.find('td', class_ ='block_content')
        #print(description1)
        #list_links =[]
        #dict_href_links={}
       # for link in description1.find_all("a", href=True):
            #if str(link["href"]).startswith("preview"):
                #print(link['href'])
               # dict_href_links[link["href"]] = None
               # link_with_www = 'http://catalogs.gsu.edu/' + link["href"]
            # print("adjusted link =", link_with_www)
               # list_links.append(link_with_www)
        #for ll in list_links:
            #print(ll)
       # print(len(list_links))
       # for i in range(len(list_links)):
          #  url1 = list_links[i]
          #  html_text = requests.get(url1).text
          #  soup1 = BeautifulSoup(html_text, 'html.parser')
          #  desc_page = soup1.find('td', class_='block_content')
            #for d in range(len(desc_page)):
          #  data_desc = desc_page.text.split('\n')[22]
          #  data_desc1 = data_desc.split('-',1)
          #  data_2.append(data_desc1[1])
        #for link in description1.find_all("a", href=True):
            #if str(link["href"]).startswith("preview"):
                #print(link['href'])
                #dict_href_links[link["href"]] = None
                #link_with_www = 'http://catalogs.gsu.edu/' + link["href"]
            # print("adjusted link =", link_with_www)
                #list_links.append(link_with_www)
        #print(len(list_links))
        #for l1 in range(len(list_links)):
            #url1 = list_links[l1]
            #html_text = requests.get(url1).text
            #soup1 = BeautifulSoup(html_text, 'html.parser')
            #desc_page = soup1.find('td', class_='block_content')
            #course2 = desc_page.find('h1').text.split('-', 1)
            
            #course_desc = desc_page.find('br')
            #for br in desc_page.findAll('br'):
                #next_s = br.nextSibling
                #if not (next_s and isinstance(next_s, NavigableString)):
                    #continue
                #next2_s = next_s.nextSibling
                #if next2_s and isinstance(next2_s,Tag) and next2_s.name == 'br':
                    #text = str(next_s).strip()
                    #if text:
                        #data_2.append(text)
        #print(data)
        #print(data_1)
        #description1 = doc.find_all("td",attrs ={"class","coursepadding"})
        #for j in range(len(description1)):
                #j1 = (description1[j].find("div").text.replace("\xa0"," "))
    
    
        
    #return data,data_1,data_2
#courses = extraction()
#courses

# %%
#def extraction1():
   # data_1 = []
   # data_1_1 = []
   # data_2_1 = []
   # data_3_1 =[]
    #data_desc= []
   # for r1 in range(1,2):
       # query_parameter = "&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D="+str(r1)+"#acalog_template_course_filter"
       # url = base_url + query_parameter
       # result = requests.get(url)
        #print(result)
       # doc1 = BeautifulSoup(result.text,"html.parser")
       # description1 = doc1.find('td', class_ ='block_content')
      #  for d1 in range(len(description1)):
           # data_3_1 = description1[d1].find("strong").text
        #print(data_3_1)
       # list_links =[]
       # dict_href_links={}
       # for link in description1.find_all("a", href=True):
           # if str(link["href"]).startswith("preview"):
                #print(link['href'])
               # dict_href_links[link["href"]] = None
               # link_with_www = 'http://catalogs.gsu.edu/' + link["href"]
            # print("adjusted link =", link_with_www)
              #  list_links.append(link_with_www)
        #for ll in list_links:
            #print(ll)
       # print(len(list_links))
       # for i in range(len(list_links)):
           # url1 = list_links[i]
           # html_text = requests.get(url1).text
          #  soup1 = BeautifulSoup(html_text, 'html.parser')
          #  desc_page = soup1.find('td', class_='block_content')
            #for d in range(len(desc_page)):
          #  data_desc = desc_page.text.split('\n')[22]
           # data_desc1 = data_desc.split('-',1)
           # data_2_1.append(data_desc1[1])
            
            
            #print(data_desc)
            #for i1 in range(len(data_desc)):
                #data_2_1 = data_desc[i1].split('-',1)
            #print(data_2_1)
            #data_2_1 = data_desc.split("-")
            #course2 = desc_page.find('h1').text.split('-', 1)
            #course_desc = desc_page.find('div').text
            #f1 = desc_page.find_all('br')
            #for br in desc_page.findAll('br'):
                #next_s = br.nextSibling
                #next_s_1 = next_s.nextSibling
                #if not (next_s and isinstance(next_s, NavigableString)):
                    #continue
               # next2_s = next_s.nextSibling
                #if next2_s and isinstance(next2_s,Tag) and next2_s.name == 'br':
                    #text = str(next_s).strip()
                   # if text:
                       # print (text)
            #print(course_desc)
            #course_id = course2[0]
            #course_title = course2[1]
        #print(course_desc)
        #for l1 in list_links:
            #print(l1)
       #data_3_1 = soup1.find('td',colspan ='2')
        #for i in range(len(description1)):
            #data_3 = description1.find('p').text
        #print(data_3)
    #return 0
#courses = extraction1()
#courses

# %%
#https://catalogs.gsu.edu/preview_course_nopop.php?catoid=4&coid=6920

# %% [markdown]
# Code used for extraction

# %%
def extraction():
    data =[]
    data_1 =[]
    data_2 =[]
    data_3 =[]
    dept =[]
    department =[]
    for r in range(1,35):
        query_parameter = "&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D="+str(r)+"#acalog_template_course_filter"
        url = base_url + query_parameter
        result = requests.get(url)
        #print(result)
        #doc = BeautifulSoup(result.text,"html.parser")
        #description = doc.find_all("td",attrs ={"class","width"})
        #print(description)
        #for i in range(len(description)):
                #q =(description[i].find("a").text.replace("\xa0"," "))
                #data0 = q.split("-",1)
                #data.append(data0[0])
                #data_1.append(data0[1])
        #desc = doc.find_all("td", class_ = 'block_content')
        #for ii in range(len(desc)):
                #d = (desc[ii].find("strong").text.replace("\xa0"," "))
                #data_3.append(d)
                
        #print(len(data))
        #print(len(data_1))
        #print(len(data_3))
        doc1 = BeautifulSoup(result.text,"html.parser")
        description1 = doc1.find('td', class_ ='block_content')
        #print(description1)
        list_links =[]
        dict_href_links={}
        for d1 in description1.find_all("strong"):
            d2 = d1.text
            if(d2 != 'HELP' and d2!= str(r)):
                department.append(d2)
        #print(department)
        for link in description1.find_all("a", href=True):
            if str(link["href"]).startswith("preview"):
                #print(link['href'])
                dict_href_links[link["href"]] = None
                link_with_www = 'http://catalogs.gsu.edu/' + link["href"]
            # print("adjusted link =", link_with_www)
                list_links.append(link_with_www)
        #for ll in list_links:
            #print(ll)
        #print(len(list_links))
        for i in range(len(list_links)):
            url1 = list_links[i]
            html_text = requests.get(url1).text
            soup1 = BeautifulSoup(html_text, 'html.parser')
            desc_page = soup1.find('td', class_='block_content')
            #print(desc_page)
            course = desc_page.find('h1').text.split('-', 1)
            #course_desc = desc_page.find('hr').find_next_sibling(text=True)
            course_id = course[0]
            data.append(course_id)
            dpt = course_id.split(" ",1)
            dept.append(dpt[0])
            course_title = course[1]
            data_1.append(course_title)
            #for d in range(len(desc_page)):
            #print(desc_page.text.split('\n'))
            data_desc = desc_page.text.split('\n')[22]
            data_desc1 = data_desc.split('-',1)
            data_2.append(data_desc1[1])
        #print(dept)
        #print(len(data))
        #print(len(data_1))
        #print(len(data_2))
        #print(len(course_id))
        #print(len(course_title))
        
    return data,data_1,data_2,department,dept
courses = extraction()
#courses
#courses_df = pd.DataFrame({'CourseNumber':courses[0], 'CourseTitle':courses[1], 'Description':courses[2], 'CourseDepartment':courses[3]})
#courses_df.to_csv('courses_temp.csv', sep = '\xa0')

# %%
courses_df = pd.DataFrame({'CourseNumber':courses[0], 'CourseTitle':courses[1], 'Description':courses[2], 'CourseDepartment':courses[4]})
courses_df.to_csv('../data/georgia_temp.csv')

# %%
courses_df
# Out:
#      CourseNumber                               CourseTitle  \
# 0      ACCT 2101                 Principles of Accounting I
# 1      ACCT 2102                Principles of Accounting II
# 2      ACCT 4101        Essentials of Financial Reporting I
# 3      ACCT 4102       Essentials of Financial Reporting II
# 4      ACCT 4111                  Intermediate Accounting I
# ...           ...                                       ...
# 3313   WGSS 4999                          Directed Readings
# 3314    WLC 3001     Learning about World Language Learning
# 3315    WLC 3002     Decentering Identities and Borders-CTW
# 3316    WLC 3300    Society in World Literature and Culture
# 3317    WLC 4001                     Global Career Pathways
#
#                                             Description CourseDepartment
# 0      Principles of Accounting I3 Credit Hours  Des...             ACCT
# 1      Principles of Accounting II3 Credit Hours Pre...             ACCT
# 2      Essentials of Financial Reporting I3 Credit H...             ACCT
# 3      Essentials of Financial Reporting II3 Credit ...             ACCT
# 4      Intermediate Accounting I3 Credit Hours Prere...             ACCT
# ...                                                 ...              ...
# 3313   Directed Readings1 to 4 Credit Hours Prerequi...             WGSS
# 3314   Learning about World Language Learning3 Credi...              WLC
# 3315   Decentering Identities and Borders-CTW3 Credi...              WLC
# 3316   Society in World Literature and Culture3 Cred...              WLC
# 3317   Global Career Pathways3 Credit Hours  Descrip...              WLC
#
# [3318 rows x 4 columns]

# %%
dept1= courses[3]
dept1 = np.unique(dept1)
print(len(dept1))
print(dept1)
# Out:
# 137
# ['Accounting' 'Acting' 'Actuarial Science' 'Africana Studies'
#  'American Sign Language' 'Anthropology' 'Applied Linguistics' 'Arabic'
#  'Art' 'Art Education' 'Art History' 'Arts Administration' 'Astronomy'
#  'Biology' 'Biomedical Science' 'Birth Through Five'
#  'Business Administration–busa' 'Business Communication' 'Chemistry'
#  'Chinese' 'College of Nursing & Health Professions'
#  'Communication Sciences and Disorders' 'Computer Information Systems'
#  'Computer Science' 'Cooperative Education'
#  'Counseling & Psychological Services' 'Creative Media Industries Study'
#  'Criminal Justice' 'Data Science' 'Dental Hygiene'
#  'Drawing, Painting, Printmaking' 'EPS/Research' 'EPS/Social Foundations'
#  'Early Childhood Education' 'Economics' 'Education'
#  'Education/Business Technology' 'Education/Curriculum & Instruction'
#  'Educational Psychology' 'Engineering' 'English'
#  'Entrepreneurship and Innovation' 'Environmental Studies'
#  'European Union Studies' 'Exceptional Children' 'Film and Media'
#  'Fin-Tech Academy' 'Finance' 'First-Year Experience' 'Folklore'
#  'Foreign Language' 'Forensic Science' 'French'
#  'GSU New Student Orientation' 'Geography' 'Geology'
#  'Georgia Film Academy' 'German' 'Gerontology' 'Global Studies'
#  'Graphic Design' 'Health Administration' 'Hindi' 'History'
#  'Homeland Security & Emerg Mgmt' 'Honors' 'Hospitality Administration'
#  'Humanities' 'Integrated Sciences' 'Intensive English Program'
#  'Interior Design' 'International Business' 'International Studies'
#  'Italian' 'Japanese' 'Jewish Studies' 'Journalism' 'Kinesiology & Health'
#  'Korean' 'Language Arts Education' 'Latin' 'Learning Technologies'
#  'Legal Studies' 'Management' 'Marketing' 'Mathematics'
#  'Mathematics Education' 'Middle East Studies'
#  'Military Science Leadership' 'Modern Greek' 'Modern Hebrew' 'Music'
#  'Music Appreciation' 'Music Technology Management' 'Natural Sciences'
#  'Neuroscience' 'Nursing' 'Nutrition' 'Occupational Therapy'
#  'Online Student Success' 'Personal Enrichment - Ce'
#  'Personal Financial Planning' 'Perspectives' 'Philosophy' 'Photography'
#  'Physical Education' 'Physical Science' 'Physics' 'Political Science'
#  'Portuguese' 'Psychology' 'Public Hlth. Policy & Behavior'
#  'Public Hlth. Population Sci.' 'Public Management & Policy'
#  'Reading Education' 'Real Estate' 'Religious Studies'
#  'Research Strategies' 'Respiratory Therapy' 'Risk Management & Insurance'
#  'Russian' 'Science Education' 'Sign Language Interpreting'
#  'Social Studies Education' 'Social Work' 'Sociology' 'Spanish'
#  'Speech Communication' 'Survey Of Business Enterprise' 'Swahili'
#  'Teaching ESL/College of ED' 'Textiles' 'Theatre'
#  'Three-Dimensional Studies' 'Urban Studies Institute'
#  'Women’s Gender and Sexuality Studies' 'World Languages and Cultures']

# %%
courses_df['CourseDepartment'] = courses_df['CourseDepartment'].replace(['EAP'],'AL')
courses_df['CourseDepartment'] = courses_df['CourseDepartment'].replace(['DHYG'],'DH')
courses_df.loc[courses_df['CourseNumber']=="HBRM 4890 ","CourseDepartment"] ="GRKM"
x1 = (courses_df.CourseDepartment.value_counts(sort=False))
xi2_1 = list(x1)
print(len(xi2_1))
xi2_1
# Out:
# 137
# [15,
#  2,
#  64,
#  73,
#  30,
#  12,
#  11,
#  4,
#  21,
#  13,
#  38,
#  1,
#  18,
#  119,
#  9,
#  10,
#  14,
#  1,
#  72,
#  25,
#  41,
#  2,
#  5,
#  31,
#  63,
#  59,
#  7,
#  55,
#  17,
#  25,
#  17,
#  30,
#  38,
#  14,
#  7,
#  10,
#  10,
#  7,
#  126,
#  6,
#  15,
#  1,
#  6,
#  13,
#  37,
#  64,
#  22,
#  5,
#  1,
#  7,
#  10,
#  1,
#  35,
#  46,
#  39,
#  25,
#  25,
#  21,
#  51,
#  21,
#  2,
#  4,
#  2,
#  109,
#  3,
#  15,
#  23,
#  1,
#  2,
#  21,
#  40,
#  11,
#  4,
#  9,
#  16,
#  2,
#  49,
#  86,
#  16,
#  2,
#  9,
#  6,
#  14,
#  3,
#  63,
#  28,
#  25,
#  30,
#  12,
#  3,
#  5,
#  135,
#  21,
#  16,
#  3,
#  42,
#  56,
#  32,
#  1,
#  1,
#  1,
#  1,
#  3,
#  60,
#  15,
#  1,
#  1,
#  44,
#  70,
#  4,
#  66,
#  18,
#  15,
#  34,
#  6,
#  12,
#  73,
#  1,
#  30,
#  27,
#  4,
#  4,
#  16,
#  2,
#  29,
#  60,
#  42,
#  35,
#  1,
#  4,
#  3,
#  15,
#  47,
#  23,
#  6,
#  52,
#  4]

# %%
lenlist1=[]
for i in range(len(dept1)):
    xi = int(xi2_1[i])
    while(xi!=0):
        lenlist1.append(dept1[i])
        xi = xi-1
        
lenlist1
p1 = pd.DataFrame(lenlist1)

# %%
p1
# Out:
#                                          0
# 0                               Accounting
# 1                               Accounting
# 2                               Accounting
# 3                               Accounting
# 4                               Accounting
# ...                                    ...
# 3313  Women’s Gender and Sexuality Studies
# 3314          World Languages and Cultures
# 3315          World Languages and Cultures
# 3316          World Languages and Cultures
# 3317          World Languages and Cultures
#
# [3318 rows x 1 columns]

# %%
courses_df['Department'] = lenlist1

# %%
courses_df
# Out:
#      CourseNumber                               CourseTitle  \
# 0      ACCT 2101                 Principles of Accounting I
# 1      ACCT 2102                Principles of Accounting II
# 2      ACCT 4101        Essentials of Financial Reporting I
# 3      ACCT 4102       Essentials of Financial Reporting II
# 4      ACCT 4111                  Intermediate Accounting I
# ...           ...                                       ...
# 3313   WGSS 4999                          Directed Readings
# 3314    WLC 3001     Learning about World Language Learning
# 3315    WLC 3002     Decentering Identities and Borders-CTW
# 3316    WLC 3300    Society in World Literature and Culture
# 3317    WLC 4001                     Global Career Pathways
#
#                                             Description CourseDepartment  \
# 0      Principles of Accounting I3 Credit Hours  Des...             ACCT
# 1      Principles of Accounting II3 Credit Hours Pre...             ACCT
# 2      Essentials of Financial Reporting I3 Credit H...             ACCT
# 3      Essentials of Financial Reporting II3 Credit ...             ACCT
# 4      Intermediate Accounting I3 Credit Hours Prere...             ACCT
# ...                                                 ...              ...
# 3313   Directed Readings1 to 4 Credit Hours Prerequi...             WGSS
# 3314   Learning about World Language Learning3 Credi...              WLC
# 3315   Decentering Identities and Borders-CTW3 Credi...              WLC
# 3316   Society in World Literature and Culture3 Cred...              WLC
# 3317   Global Career Pathways3 Credit Hours  Descrip...              WLC
#
#                                 Department
# 0                               Accounting
# 1                               Accounting
# 2                               Accounting
# 3                               Accounting
# 4                               Accounting
# ...                                    ...
# 3313  Women’s Gender and Sexuality Studies
# 3314          World Languages and Cultures
# 3315          World Languages and Cultures
# 3316          World Languages and Cultures
# 3317          World Languages and Cultures
#
# [3318 rows x 5 columns]

# %%
courses_df = courses_df.drop(['CourseDepartment'],axis =1)
courses_df
# Out:
#      CourseNumber                               CourseTitle  \
# 0      ACCT 2101                 Principles of Accounting I
# 1      ACCT 2102                Principles of Accounting II
# 2      ACCT 4101        Essentials of Financial Reporting I
# 3      ACCT 4102       Essentials of Financial Reporting II
# 4      ACCT 4111                  Intermediate Accounting I
# ...           ...                                       ...
# 3313   WGSS 4999                          Directed Readings
# 3314    WLC 3001     Learning about World Language Learning
# 3315    WLC 3002     Decentering Identities and Borders-CTW
# 3316    WLC 3300    Society in World Literature and Culture
# 3317    WLC 4001                     Global Career Pathways
#
#                                             Description  \
# 0      Principles of Accounting I3 Credit Hours  Des...
# 1      Principles of Accounting II3 Credit Hours Pre...
# 2      Essentials of Financial Reporting I3 Credit H...
# 3      Essentials of Financial Reporting II3 Credit ...
# 4      Intermediate Accounting I3 Credit Hours Prere...
# ...                                                 ...
# 3313   Directed Readings1 to 4 Credit Hours Prerequi...
# 3314   Learning about World Language Learning3 Credi...
# 3315   Decentering Identities and Borders-CTW3 Credi...
# 3316   Society in World Literature and Culture3 Cred...
# 3317   Global Career Pathways3 Credit Hours  Descrip...
#
#                                 Department
# 0                               Accounting
# 1                               Accounting
# 2                               Accounting
# 3                               Accounting
# 4                               Accounting
# ...                                    ...
# 3313  Women’s Gender and Sexuality Studies
# 3314          World Languages and Cultures
# 3315          World Languages and Cultures
# 3316          World Languages and Cultures
# 3317          World Languages and Cultures
#
# [3318 rows x 4 columns]

# %%
courses_df.rename(columns={'Description':'CourseDescription','Department':'CourseDepartment'}, inplace = True)
courses_df
# Out:
#      CourseNumber                               CourseTitle  \
# 0      ACCT 2101                 Principles of Accounting I
# 1      ACCT 2102                Principles of Accounting II
# 2      ACCT 4101        Essentials of Financial Reporting I
# 3      ACCT 4102       Essentials of Financial Reporting II
# 4      ACCT 4111                  Intermediate Accounting I
# ...           ...                                       ...
# 3313   WGSS 4999                          Directed Readings
# 3314    WLC 3001     Learning about World Language Learning
# 3315    WLC 3002     Decentering Identities and Borders-CTW
# 3316    WLC 3300    Society in World Literature and Culture
# 3317    WLC 4001                     Global Career Pathways
#
#                                       CourseDescription  \
# 0      Principles of Accounting I3 Credit Hours  Des...
# 1      Principles of Accounting II3 Credit Hours Pre...
# 2      Essentials of Financial Reporting I3 Credit H...
# 3      Essentials of Financial Reporting II3 Credit ...
# 4      Intermediate Accounting I3 Credit Hours Prere...
# ...                                                 ...
# 3313   Directed Readings1 to 4 Credit Hours Prerequi...
# 3314   Learning about World Language Learning3 Credi...
# 3315   Decentering Identities and Borders-CTW3 Credi...
# 3316   Society in World Literature and Culture3 Cred...
# 3317   Global Career Pathways3 Credit Hours  Descrip...
#
#                           CourseDepartment
# 0                               Accounting
# 1                               Accounting
# 2                               Accounting
# 3                               Accounting
# 4                               Accounting
# ...                                    ...
# 3313  Women’s Gender and Sexuality Studies
# 3314          World Languages and Cultures
# 3315          World Languages and Cultures
# 3316          World Languages and Cultures
# 3317          World Languages and Cultures
#
# [3318 rows x 4 columns]

# %%
courses_df.to_csv('../data/georgia_undergrad_final.csv', index = False)

# %%
courses_df.isnull().sum()
# Out:
# CourseNumber         0
# CourseTitle          0
# CourseDescription    0
# CourseDepartment     0
# dtype: int64

# %%
courses_df[courses_df['CourseNumber']=='ACCT 2101 ']
# Out:
#   CourseNumber                  CourseTitle  \
# 0   ACCT 2101    Principles of Accounting I
#
#                                    CourseDescription CourseDepartment
# 0   Principles of Accounting I3 Credit Hours  Des...       Accounting

# %%
#def extraction():
    #data =[]
   # data_1 =[]
   # data_2 =[]
   # data_3 =[]
   # dept =[]
    #department =[]
   # for r in range(1,2):
       # query_parameter = "&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D="+str(r)+"#acalog_template_course_filter"
       # url = base_url + query_parameter
        #result = requests.get(url)
        #print(result)
        #doc = BeautifulSoup(result.text,"html.parser")
        #description = doc.find_all("td",attrs ={"class","width"})
        #print(description)
        #for i in range(len(description)):
                #q =(description[i].find("a").text.replace("\xa0"," "))
                #data0 = q.split("-",1)
                #data.append(data0[0])
               # data_1.append(data0[1])
        #desc = doc.find_all("td", class_ = 'block_content')
        #for ii in range(len(desc)):
                #d = (desc[ii].find("strong").text.replace("\xa0"," "))
                #data_3.append(d)
                
        #print(len(data))
        #print(len(data_1))
        #print(len(data_3))
       # doc1 = BeautifulSoup(result.text,"html.parser")
       # description1 = doc1.find('td', class_ ='block_content')
        #print(description1)
      #  list_links =[]
       # dict_href_links={}
       # for d1 in description1.find_all("strong"):
           # d2 = d1.text
           # if(d2 != 'HELP' and d2!= str(r)):
             #   department.append(d2)
       # print(department)
       # for link in description1.find_all("a", href=True):
           # if str(link["href"]).startswith("preview"):
                #print(link['href'])
               # dict_href_links[link["href"]] = None
              #  link_with_www = 'http://catalogs.gsu.edu/' + link["href"]
            # print("adjusted link =", link_with_www)
               # list_links.append(link_with_www)
        #for ll in list_links:
            #print(ll)
        #print(len(list_links))
        #for i in range(len(list_links)):
            #url1 = list_links[i]
           # html_text = requests.get(url1).text
           # soup1 = BeautifulSoup(html_text, 'html.parser')
           # desc_page = soup1.find('td', class_='block_content')
            #print(desc_page)
            #course = desc_page.find('h1').text.split('-', 1)
            #course_desc = desc_page.find('hr').find_next_sibling(text=True)
            #course_id = course[0]
            #data.append(course_id)
            #dpt = course_id.split(" ",1)
            #dept.append(dpt[0])
           # course_title = course[1]
            #data_1.append(course_title)
           # for d in range(len(desc_page)):
               # print(desc_page.text.split('\n'))
            #data_desc = desc_page.text.split('\n')[22]
            #data_desc1 = data_desc.split('-',1)
            #data_2.append(data_desc1[1])
        #print(dept)
        #print(len(data))
        #print(len(data_1))
        #print(len(data_2))
        #print(len(course_id))
        #print(len(course_title))
        
    #return data,data_1,data_2,department,dept
#courses = extraction()
# Out:
# ['Accounting', 'Acting', 'Africana Studies', 'Anthropology']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2101 - Principles of Accounting I3 Credit Hours  Description Principles of Accounting I is an introduction to the principles of financial accounting. The course focuses on analyzing business transactions to chart their effects on the results of operations, the cash flows, and the financial position of businesses organized for profit. Emphasis is on using financial information from a decision-making perspective to optimize the outcomes of business decisions. Topics include recording, reporting, and analyzing assets, liabilities, stockholders’ equity, revenues, and expenses.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 2102 - Principles of Accounting II3 Credit Hours Prerequisites: ACCT 2101\xa0. Description Principles of Accounting II is an introduction to the principles of managerial accounting. Emphasis is given to the development and use of accounting information to support managerial decision-making in manufacturing, service, and merchandising operations. Topics include managerial concepts and systems, analyses for decision making, and planning and control.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4101 - Essentials of Financial Reporting I3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to value and record operating activities in the accounting cycle, analyze data to provide insights about business operations and performance, and apply critical thinking to support evidence-based conclusions including ethical dimensions.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4102 - Essentials of Financial Reporting II3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher. ACCT 4101\xa0\xa0and BCOM 3950\xa0\xa0with a grade of C- or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to identify, analyze and record the assets, liabilities and equity of an enterprise, account for and report complex business transactions and disclosures, apply financial accounting theory, professional standards and judgment to real world business transactions, and analyze firm performance using financial accounting information.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4102 - Essentials of Financial Reporting II3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher. ACCT 4101\xa0\xa0and BCOM 3950\xa0\xa0with a grade of C- or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to identify, analyze and record the assets, liabilities and equity of an enterprise, account for and report complex business transactions and disclosures, apply financial accounting theory, professional standards and judgment to real world business transactions, and analyze firm performance using financial accounting information.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4102 - Essentials of Financial Reporting II3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher. ACCT 4101\xa0\xa0and BCOM 3950\xa0\xa0with a grade of C- or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to identify, analyze and record the assets, liabilities and equity of an enterprise, account for and report complex business transactions and disclosures, apply financial accounting theory, professional standards and judgment to real world business transactions, and analyze firm performance using financial accounting information.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4102 - Essentials of Financial Reporting II3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher. ACCT 4101\xa0\xa0and BCOM 3950\xa0\xa0with a grade of C- or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to identify, analyze and record the assets, liabilities and equity of an enterprise, account for and report complex business transactions and disclosures, apply financial accounting theory, professional standards and judgment to real world business transactions, and analyze firm performance using financial accounting information.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4102 - Essentials of Financial Reporting II3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher. ACCT 4101\xa0\xa0and BCOM 3950\xa0\xa0with a grade of C- or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to identify, analyze and record the assets, liabilities and equity of an enterprise, account for and report complex business transactions and disclosures, apply financial accounting theory, professional standards and judgment to real world business transactions, and analyze firm performance using financial accounting information.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4102 - Essentials of Financial Reporting II3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher. ACCT 4101\xa0\xa0and BCOM 3950\xa0\xa0with a grade of C- or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to identify, analyze and record the assets, liabilities and equity of an enterprise, account for and report complex business transactions and disclosures, apply financial accounting theory, professional standards and judgment to real world business transactions, and analyze firm performance using financial accounting information.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4102 - Essentials of Financial Reporting II3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher. ACCT 4101\xa0\xa0and BCOM 3950\xa0\xa0with a grade of C- or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to identify, analyze and record the assets, liabilities and equity of an enterprise, account for and report complex business transactions and disclosures, apply financial accounting theory, professional standards and judgment to real world business transactions, and analyze firm performance using financial accounting information.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ACCT 4102 - Essentials of Financial Reporting II3 Credit Hours Prerequisites: ACCT 2101\xa0\xa0and ACCT 2102\xa0\xa0with a grade of B or higher. ACCT 4101\xa0\xa0and BCOM 3950\xa0\xa0with a grade of C- or higher.Requirements: Must meet RCB upper division course requirements and 45 semester hours.    Description In this course students will learn how to identify, analyze and record the assets, liabilities and equity of an enterprise, account for and report complex business transactions and disclosures, apply financial accounting theory, professional standards and judgment to real world business transactions, and analyze firm performance using financial accounting information.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ...
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4111 - Anthropology of Self and Emotion3 Credit Hours Prerequisites: ANTH 2020\xa0\xa0with a C or higher, or consent of instructor. Description(Same as WGSS 4111\xa0.) This course draws upon readings in anthropological theory and ethnography to consider the cultural construction of self-hood, identity, and feelings, with an emphasis on the historical specificity of particular experiences, how they may be influenced by factors such as capitalism, how they may change over time, and the significance of gender.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4111 - Anthropology of Self and Emotion3 Credit Hours Prerequisites: ANTH 2020\xa0\xa0with a C or higher, or consent of instructor. Description(Same as WGSS 4111\xa0.) This course draws upon readings in anthropological theory and ethnography to consider the cultural construction of self-hood, identity, and feelings, with an emphasis on the historical specificity of particular experiences, how they may be influenced by factors such as capitalism, how they may change over time, and the significance of gender.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4111 - Anthropology of Self and Emotion3 Credit Hours Prerequisites: ANTH 2020\xa0\xa0with a C or higher, or consent of instructor. Description(Same as WGSS 4111\xa0.) This course draws upon readings in anthropological theory and ethnography to consider the cultural construction of self-hood, identity, and feelings, with an emphasis on the historical specificity of particular experiences, how they may be influenced by factors such as capitalism, how they may change over time, and the significance of gender.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4111 - Anthropology of Self and Emotion3 Credit Hours Prerequisites: ANTH 2020\xa0\xa0with a C or higher, or consent of instructor. Description(Same as WGSS 4111\xa0.) This course draws upon readings in anthropological theory and ethnography to consider the cultural construction of self-hood, identity, and feelings, with an emphasis on the historical specificity of particular experiences, how they may be influenced by factors such as capitalism, how they may change over time, and the significance of gender.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4111 - Anthropology of Self and Emotion3 Credit Hours Prerequisites: ANTH 2020\xa0\xa0with a C or higher, or consent of instructor. Description(Same as WGSS 4111\xa0.) This course draws upon readings in anthropological theory and ethnography to consider the cultural construction of self-hood, identity, and feelings, with an emphasis on the historical specificity of particular experiences, how they may be influenced by factors such as capitalism, how they may change over time, and the significance of gender.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4111 - Anthropology of Self and Emotion3 Credit Hours Prerequisites: ANTH 2020\xa0\xa0with a C or higher, or consent of instructor. Description(Same as WGSS 4111\xa0.) This course draws upon readings in anthropological theory and ethnography to consider the cultural construction of self-hood, identity, and feelings, with an emphasis on the historical specificity of particular experiences, how they may be influenced by factors such as capitalism, how they may change over time, and the significance of gender.          ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['', '', '', '', 'HELP', '2021-2022 Undergraduate Catalog ', 'Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ', '', '', 'ANTH 4112 - Modernity and Identity4 Credit Hours  Description Representations of modernity in postcolonial and metropolitan nation-states. National identities and their articulations with gender, class, and race.  Global Scholars course.        ', '\xa0Back to Top | Print-Friendly Page (opens a new window)', '', '', 'Facebook this Page (opens a new window)', '', '', '', '', 'Tweet this Page (opens a new window)', '', '', '', 'Add to Portfolio (opens a new window)', ' ']
# ['ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACCT', 'ACT', 'ACT', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'AAS', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH', 'ANTH']

# %%
undergrad_df = pd.read_csv('../data/georgia_undergrad_final.csv')
undergrad_df
# Out:
#      CourseNumber                               CourseTitle  \
# 0      ACCT 2101                 Principles of Accounting I
# 1      ACCT 2102                Principles of Accounting II
# 2      ACCT 4101        Essentials of Financial Reporting I
# 3      ACCT 4102       Essentials of Financial Reporting II
# 4      ACCT 4111                  Intermediate Accounting I
# ...           ...                                       ...
# 3313   WGSS 4999                          Directed Readings
# 3314    WLC 3001     Learning about World Language Learning
# 3315    WLC 3002     Decentering Identities and Borders-CTW
# 3316    WLC 3300    Society in World Literature and Culture
# 3317    WLC 4001                     Global Career Pathways
#
#                                       CourseDescription  \
# 0      Principles of Accounting I3 Credit Hours  Des...
# 1      Principles of Accounting II3 Credit Hours Pre...
# 2      Essentials of Financial Reporting I3 Credit H...
# 3      Essentials of Financial Reporting II3 Credit ...
# 4      Intermediate Accounting I3 Credit Hours Prere...
# ...                                                 ...
# 3313   Directed Readings1 to 4 Credit Hours Prerequi...
# 3314   Learning about World Language Learning3 Credi...
# 3315   Decentering Identities and Borders-CTW3 Credi...
# 3316   Society in World Literature and Culture3 Cred...
# 3317   Global Career Pathways3 Credit Hours  Descrip...
#
#                           CourseDepartment
# 0                               Accounting
# 1                               Accounting
# 2                               Accounting
# 3                               Accounting
# 4                               Accounting
# ...                                    ...
# 3313  Women’s Gender and Sexuality Studies
# 3314          World Languages and Cultures
# 3315          World Languages and Cultures
# 3316          World Languages and Cultures
# 3317          World Languages and Cultures
#
# [3318 rows x 4 columns]
