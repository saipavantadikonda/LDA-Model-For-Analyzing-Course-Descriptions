# %%
import pandas as pd
import numpy as np
import re
import requests

# %%
uncc_df = pd.read_csv("../data/uncc_temp1.csv")

# %%
uncc_df
# Out:
#       Unnamed: 0 CourseNumber                                  CourseTitle  \
# 0              0   ACCT 5220                                   Income Tax
# 1              1   ACCT 5311           Intermediate Financial Reporting I
# 2              2   ACCT 5312          Intermediate Financial Reporting II
# 3              3   ACCT 6110                    Tax Research and Planning
# 4              4   ACCT 6120    Taxation of Corporations and Shareholders
# ...          ...          ...                                          ...
# 2997        2997   WGST 6601          Theoretical Approaches to Sexuality
# 2998        2998   WGST 6602             Theoretical Approaches to Gender
# 2999        2999   WGST 6603                   Language, Gender and Power
# 3000        3000   WGST 6627         Feminist Theory and its Applications
# 3001        3001   WGST 6800                    Directed Reading/Research
#
#                                       CourseDescription  \
# ...

# %%
uncc_df['CourseDescription']
# Out:
# 0       An introduction to the Federal income tax syst...
# 1       Analysis of the financial reporting requiremen...
# 2       A continuation of ACCT 5311  with emphasis on ...
# 3       Tax research techniques applicable to federal ...
# 4       Examines the federal and state tax law applica...
#                               ...
# 2997    An interdisciplinary examination of the histor...
# 2998    An interdisciplinary examination of the core t...
# 2999    An examination of the ways language constructs...
# 3000    An examination of selected works in feminist t...
# 3001    Independent investigation of a problem or a to...
# Name: CourseDescription, Length: 3002, dtype: object

# %%
uncc_df['CourseDescription'][0]
# Out:
# 'An introduction to the Federal income tax system with emphasis on concepts and procedures applicable to all types of entities. Most Recently Offered (Day): Course has not been offered at this time in the past 3 yearsMost Recently Offered (Evening): Fall 2016, Fall 2015, Fall 2014'

# %%
lst1 = list(uncc_df['CourseDescription'])
lst1
# Out:
# ['An introduction to the Federal income tax system with emphasis on concepts and procedures applicable to all types of entities. Most Recently Offered (Day): Course has not been offered at this time in the past 3 yearsMost Recently Offered (Evening): Fall 2016, Fall 2015, Fall 2014',
#  'Analysis of the financial reporting requirements of corporations with emphasis on the conceptual framework and accounting for assets.Restriction(s): Enrollment in the MACC program.Prerequisite(s): ACCT 2121 or equivalent. Most Recently Offered (Day): Summer 2016, Summer 2015Most Recently Offered (Evening): Fall 2016, Fall 2015',
# ...

# %%
lst2= []
for i in range(len(lst1)):
    q = lst1[i].split("Most Recently Offered")
    lst2.append(q[0])

# %%
lst2
# Out:
# ['An introduction to the Federal income tax system with emphasis on concepts and procedures applicable to all types of entities. ',
#  'Analysis of the financial reporting requirements of corporations with emphasis on the conceptual framework and accounting for assets.Restriction(s): Enrollment in the MACC program.Prerequisite(s): ACCT 2121 or equivalent. ',
#  'A continuation of ACCT 5311\xa0\xa0with emphasis on financial reporting for liabilities and stockholder’s equity. \xa0Also, a number of special topics, including the accounting for investments and the statement of cash flows.Restriction(s): Enrollment in the MACC program.Prerequisite(s): ACCT 3311 or ACCT 5311\xa0\xa0with grade of B or above. ',
# ...

# %%
lst3 = []
for j in range(len(lst2)):
    q1 = lst2[j].split("Restriction(s)")
    lst3.append(q1[0])

# %%
lst3
# Out:
# ['An introduction to the Federal income tax system with emphasis on concepts and procedures applicable to all types of entities. ',
#  'Analysis of the financial reporting requirements of corporations with emphasis on the conceptual framework and accounting for assets.',
#  'A continuation of ACCT 5311\xa0\xa0with emphasis on financial reporting for liabilities and stockholder’s equity. \xa0Also, a number of special topics, including the accounting for investments and the statement of cash flows.',
#  'Tax research techniques applicable to federal tax law affecting individuals, corporations and partnerships, including use of traditional and computerized tax services to solve tax problems. Emphasis on tax planning principles and related tax practice matters, including handling tax compliance issues and dealing with the Internal Revenue Service. ',
# ...

# %%
lst4 = []
for k in range(len(lst3)):
    q2 = lst3[k].split("Prerequisite(s)")
    lst4.append(q2[0])

# %%
lst4
# Out:
# ['An introduction to the Federal income tax system with emphasis on concepts and procedures applicable to all types of entities. ',
#  'Analysis of the financial reporting requirements of corporations with emphasis on the conceptual framework and accounting for assets.',
#  'A continuation of ACCT 5311\xa0\xa0with emphasis on financial reporting for liabilities and stockholder’s equity. \xa0Also, a number of special topics, including the accounting for investments and the statement of cash flows.',
#  'Tax research techniques applicable to federal tax law affecting individuals, corporations and partnerships, including use of traditional and computerized tax services to solve tax problems. Emphasis on tax planning principles and related tax practice matters, including handling tax compliance issues and dealing with the Internal Revenue Service. ',
# ...

# %%
lst5 = []
for l in range(len(lst4)):
    q3 = lst4[l].split("Pre- or Corequisite(s)")
    lst5.append(q3[0])

# %%
lst5
# Out:
# ['An introduction to the Federal income tax system with emphasis on concepts and procedures applicable to all types of entities. ',
#  'Analysis of the financial reporting requirements of corporations with emphasis on the conceptual framework and accounting for assets.',
#  'A continuation of ACCT 5311\xa0\xa0with emphasis on financial reporting for liabilities and stockholder’s equity. \xa0Also, a number of special topics, including the accounting for investments and the statement of cash flows.',
#  'Tax research techniques applicable to federal tax law affecting individuals, corporations and partnerships, including use of traditional and computerized tax services to solve tax problems. Emphasis on tax planning principles and related tax practice matters, including handling tax compliance issues and dealing with the Internal Revenue Service. ',
# ...

# %%
lst6 = []
for m in range(len(lst5)):
    q4 = lst5[m].split("Repeatability:")
    lst6.append(q4[0])

# %%
lst6
# Out:
# ['An introduction to the Federal income tax system with emphasis on concepts and procedures applicable to all types of entities. ',
#  'Analysis of the financial reporting requirements of corporations with emphasis on the conceptual framework and accounting for assets.',
#  'A continuation of ACCT 5311\xa0\xa0with emphasis on financial reporting for liabilities and stockholder’s equity. \xa0Also, a number of special topics, including the accounting for investments and the statement of cash flows.',
#  'Tax research techniques applicable to federal tax law affecting individuals, corporations and partnerships, including use of traditional and computerized tax services to solve tax problems. Emphasis on tax planning principles and related tax practice matters, including handling tax compliance issues and dealing with the Internal Revenue Service. ',
# ...

# %%
lst7 = []
for n in range(len(lst6)):
    q5 = lst6[n].split("Corequisite(s)")
    lst7.append(q5[0])

# %%
lst7
# Out:
# ['An introduction to the Federal income tax system with emphasis on concepts and procedures applicable to all types of entities. ',
#  'Analysis of the financial reporting requirements of corporations with emphasis on the conceptual framework and accounting for assets.',
#  'A continuation of ACCT 5311\xa0\xa0with emphasis on financial reporting for liabilities and stockholder’s equity. \xa0Also, a number of special topics, including the accounting for investments and the statement of cash flows.',
#  'Tax research techniques applicable to federal tax law affecting individuals, corporations and partnerships, including use of traditional and computerized tax services to solve tax problems. Emphasis on tax planning principles and related tax practice matters, including handling tax compliance issues and dealing with the Internal Revenue Service. ',
# ...

# %%
p1 = pd.DataFrame(lst7)
p1
# Out:
#                                                       0
# 0     An introduction to the Federal income tax syst...
# 1     Analysis of the financial reporting requiremen...
# 2     A continuation of ACCT 5311  with emphasis on ...
# 3     Tax research techniques applicable to federal ...
# 4     Examines the federal and state tax law applica...
# ...                                                 ...
# 2997  An interdisciplinary examination of the histor...
# 2998  An interdisciplinary examination of the core t...
# 2999  An examination of the ways language constructs...
# 3000  An examination of selected works in feminist t...
# 3001  Independent investigation of a problem or a to...
#
# [3002 rows x 1 columns]

# %%
uncc_df['CourseDescription'] = lst7
uncc_df
# Out:
#       Unnamed: 0 CourseNumber                                  CourseTitle  \
# 0              0   ACCT 5220                                   Income Tax
# 1              1   ACCT 5311           Intermediate Financial Reporting I
# 2              2   ACCT 5312          Intermediate Financial Reporting II
# 3              3   ACCT 6110                    Tax Research and Planning
# 4              4   ACCT 6120    Taxation of Corporations and Shareholders
# ...          ...          ...                                          ...
# 2997        2997   WGST 6601          Theoretical Approaches to Sexuality
# 2998        2998   WGST 6602             Theoretical Approaches to Gender
# 2999        2999   WGST 6603                   Language, Gender and Power
# 3000        3000   WGST 6627         Feminist Theory and its Applications
# 3001        3001   WGST 6800                    Directed Reading/Research
#
#                                       CourseDescription  \
# ...

# %%
uncc_df["CourseDescription"][1897]
# Out:
# 'Harmonic functions, mean-value theorem, maximum principle, Green’s representation for the solution of the Dirichlet problem for Laplace’s equation; Poisson’s equations and the Poisson formula; statement and proof of the existence theorem for general second-order elliptic operators, generalized maximum principles; Sobolev spaces. Evolution equations involving elliptic operators, such as the heat or wave equations, may also be introduced.'

# %%
uncc_df['University'] = 'UNCC'
uncc_df
# Out:
#       Unnamed: 0 CourseNumber                                  CourseTitle  \
# 0              0   ACCT 5220                                   Income Tax
# 1              1   ACCT 5311           Intermediate Financial Reporting I
# 2              2   ACCT 5312          Intermediate Financial Reporting II
# 3              3   ACCT 6110                    Tax Research and Planning
# 4              4   ACCT 6120    Taxation of Corporations and Shareholders
# ...          ...          ...                                          ...
# 2997        2997   WGST 6601          Theoretical Approaches to Sexuality
# 2998        2998   WGST 6602             Theoretical Approaches to Gender
# 2999        2999   WGST 6603                   Language, Gender and Power
# 3000        3000   WGST 6627         Feminist Theory and its Applications
# 3001        3001   WGST 6800                    Directed Reading/Research
#
#                                       CourseDescription  \
# ...

# %%
uncc_df.dtypes
# Out:
# Unnamed: 0            int64
# CourseNumber         object
# CourseTitle          object
# CourseDescription    object
# CourseDepartment     object
# University           object
# dtype: object

# %%
uncc_df.to_csv('../data/uncc_final.csv', index = None)

# %%
df1 = pd.read_csv('../data/uncc_final.csv')
df1
# Out:
#       Unnamed: 0 CourseNumber                                  CourseTitle  \
# 0              0   ACCT 5220                                   Income Tax
# 1              1   ACCT 5311           Intermediate Financial Reporting I
# 2              2   ACCT 5312          Intermediate Financial Reporting II
# 3              3   ACCT 6110                    Tax Research and Planning
# 4              4   ACCT 6120    Taxation of Corporations and Shareholders
# ...          ...          ...                                          ...
# 2997        2997   WGST 6601          Theoretical Approaches to Sexuality
# 2998        2998   WGST 6602             Theoretical Approaches to Gender
# 2999        2999   WGST 6603                   Language, Gender and Power
# 3000        3000   WGST 6627         Feminist Theory and its Applications
# 3001        3001   WGST 6800                    Directed Reading/Research
#
#                                       CourseDescription  \
# ...

# %%
df1 = df1.loc[:, ~df1.columns.str.contains('^Unnamed')]
df1
# Out:
#      CourseNumber                                  CourseTitle  \
# 0      ACCT 5220                                   Income Tax
# 1      ACCT 5311           Intermediate Financial Reporting I
# 2      ACCT 5312          Intermediate Financial Reporting II
# 3      ACCT 6110                    Tax Research and Planning
# 4      ACCT 6120    Taxation of Corporations and Shareholders
# ...           ...                                          ...
# 2997   WGST 6601          Theoretical Approaches to Sexuality
# 2998   WGST 6602             Theoretical Approaches to Gender
# 2999   WGST 6603                   Language, Gender and Power
# 3000   WGST 6627         Feminist Theory and its Applications
# 3001   WGST 6800                    Directed Reading/Research
#
#                                       CourseDescription  \
# 0     An introduction to the Federal income tax syst...
# 1     Analysis of the financial reporting requiremen...
# ...

# %%
ncsu_df = pd.read_csv('../data/courses_temp1.csv')
ncsu_df
# Out:
#         CourseNumber                            CourseTitle  \
# 0            DSC 495         Special Topics in Data Science
# 1            ACC 200  Introduction to Managerial Accounting
# 2            ACC 210        Concepts of Financial Reporting
# 3            ACC 220  Introduction to Managerial Accounting
# 4            ACC 230             Individual Income Taxation
# ...              ...                                    ...
# 7256   ZO 553/FW 553         Principles Of Wildlife Science
# 7257  ZO 582/ENT 582      Medical and Veterinary Entomology
# 7258          ZO 790                         Special Topics
# 7259          ZO 791              Topics In Animal Behavior
# 7260          ZO 829                         Special Topics
#
#                                       CourseDescription  \
# 0     Offered as needed to present material not norm...
# 1     Analysis of  accounting data that are useful i...
# 2     Financial reporting concepts, the accounting i...
# ...

# %%
ncsu_df['University']= 'NCSU'
ncsu_df
# Out:
#         CourseNumber                            CourseTitle  \
# 0            DSC 495         Special Topics in Data Science
# 1            ACC 200  Introduction to Managerial Accounting
# 2            ACC 210        Concepts of Financial Reporting
# 3            ACC 220  Introduction to Managerial Accounting
# 4            ACC 230             Individual Income Taxation
# ...              ...                                    ...
# 7256   ZO 553/FW 553         Principles Of Wildlife Science
# 7257  ZO 582/ENT 582      Medical and Veterinary Entomology
# 7258          ZO 790                         Special Topics
# 7259          ZO 791              Topics In Animal Behavior
# 7260          ZO 829                         Special Topics
#
#                                       CourseDescription  \
# 0     Offered as needed to present material not norm...
# 1     Analysis of  accounting data that are useful i...
# 2     Financial reporting concepts, the accounting i...
# ...

# %%
ncsu_df.to_csv('../data/ncsu_final.csv', index = None)

# %%
df2 = pd.read_csv('../data/ncsu_final.csv')
df2
# Out:
#         CourseNumber                            CourseTitle  \
# 0            DSC 495         Special Topics in Data Science
# 1            ACC 200  Introduction to Managerial Accounting
# 2            ACC 210        Concepts of Financial Reporting
# 3            ACC 220  Introduction to Managerial Accounting
# 4            ACC 230             Individual Income Taxation
# ...              ...                                    ...
# 7256   ZO 553/FW 553         Principles Of Wildlife Science
# 7257  ZO 582/ENT 582      Medical and Veterinary Entomology
# 7258          ZO 790                         Special Topics
# 7259          ZO 791              Topics In Animal Behavior
# 7260          ZO 829                         Special Topics
#
#                                       CourseDescription  \
# 0     Offered as needed to present material not norm...
# 1     Analysis of  accounting data that are useful i...
# 2     Financial reporting concepts, the accounting i...
# ...

# %%
unc_df = pd.read_csv('../data/chapel_temp1.csv')
unc_df
# Out:
#      CourseNumber                                        CourseTitle  \
# 0        AERO 101  Heritage and Values of the United States Air F...
# 1        AERO 102  Heritage and Values of the United States Air F...
# 2        AERO 190                                            Seminar
# 3        AERO 196                                  Independent Study
# 4        AERO 201         Team and Air Force Leadership Fundamentals
# ...           ...                                                ...
# 9843     WOLO 403                             Intermediate Wolof III
# 9844     WOLO 404                              Intermediate Wolof IV
# 9845     WOLO 405                                   Advanced Wolof V
# 9846     WOLO 406                                  Advanced Wolof VI
# 9847     MAYA 401                       Introduction to Yucatec Maya
#
#                                       CourseDescription       CourseDepartment
# ...

# %%
unc_df['University']= 'UNC'
unc_df
# Out:
#      CourseNumber                                        CourseTitle  \
# 0        AERO 101  Heritage and Values of the United States Air F...
# 1        AERO 102  Heritage and Values of the United States Air F...
# 2        AERO 190                                            Seminar
# 3        AERO 196                                  Independent Study
# 4        AERO 201         Team and Air Force Leadership Fundamentals
# ...           ...                                                ...
# 9843     WOLO 403                             Intermediate Wolof III
# 9844     WOLO 404                              Intermediate Wolof IV
# 9845     WOLO 405                                   Advanced Wolof V
# 9846     WOLO 406                                  Advanced Wolof VI
# 9847     MAYA 401                       Introduction to Yucatec Maya
#
#                                       CourseDescription  \
# 0     Part one of a two-part course that examines th...
# ...

# %%
unc_df.to_csv('../data/chapel_final.csv', index = None)

# %%
df3 = pd.read_csv('../data/chapel_final.csv')
df3
# Out:
#      CourseNumber                                        CourseTitle  \
# 0        AERO 101  Heritage and Values of the United States Air F...
# 1        AERO 102  Heritage and Values of the United States Air F...
# 2        AERO 190                                            Seminar
# 3        AERO 196                                  Independent Study
# 4        AERO 201         Team and Air Force Leadership Fundamentals
# ...           ...                                                ...
# 9843     WOLO 403                             Intermediate Wolof III
# 9844     WOLO 404                              Intermediate Wolof IV
# 9845     WOLO 405                                   Advanced Wolof V
# 9846     WOLO 406                                  Advanced Wolof VI
# 9847     MAYA 401                       Introduction to Yucatec Maya
#
#                                       CourseDescription  \
# 0     Part one of a two-part course that examines th...
# ...

# %%
gsuu_df = pd.read_csv('../data/georgia_undergrad_final.csv')
gsuu_df
# Out:
#      CourseNumber                               CourseTitle  \
# 0      ACCT 2101                 Principles of Accounting I
# 1      ACCT 2102                Principles of Accounting II
# 2      ACCT 4101        Essentials of Financial Reporting I
# 3      ACCT 4102       Essentials of Financial Reporting II
# 4      ACCT 4111                  Intermediate Accounting I
# ...           ...                                       ...
# 3313   WGSS 4999                          Directed Readings
# 3314    WLC 3001     Learning about World Language Learning
# 3315    WLC 3002     Decentering Identities and Borders-CTW
# 3316    WLC 3300    Society in World Literature and Culture
# 3317    WLC 4001                     Global Career Pathways
#
#                                       CourseDescription  \
# 0      Principles of Accounting I3 Credit Hours  Des...
# 1      Principles of Accounting II3 Credit Hours Pre...
# 2      Essentials of Financial Reporting I3 Credit H...
# ...

# %%
gsuu_df['University']= 'GSU'
gsuu_df
# Out:
#      CourseNumber                               CourseTitle  \
# 0      ACCT 2101                 Principles of Accounting I
# 1      ACCT 2102                Principles of Accounting II
# 2      ACCT 4101        Essentials of Financial Reporting I
# 3      ACCT 4102       Essentials of Financial Reporting II
# 4      ACCT 4111                  Intermediate Accounting I
# ...           ...                                       ...
# 3313   WGSS 4999                          Directed Readings
# 3314    WLC 3001     Learning about World Language Learning
# 3315    WLC 3002     Decentering Identities and Borders-CTW
# 3316    WLC 3300    Society in World Literature and Culture
# 3317    WLC 4001                     Global Career Pathways
#
#                                       CourseDescription  \
# 0      Principles of Accounting I3 Credit Hours  Des...
# 1      Principles of Accounting II3 Credit Hours Pre...
# 2      Essentials of Financial Reporting I3 Credit H...
# ...

# %%
gsuu_df.to_csv('../data/gsu_ug_final.csv', index = None)

# %%
df4 = pd.read_csv('../data/gsu_ug_final.csv')
df4
# Out:
#      CourseNumber                               CourseTitle  \
# 0      ACCT 2101                 Principles of Accounting I
# 1      ACCT 2102                Principles of Accounting II
# 2      ACCT 4101        Essentials of Financial Reporting I
# 3      ACCT 4102       Essentials of Financial Reporting II
# 4      ACCT 4111                  Intermediate Accounting I
# ...           ...                                       ...
# 3313   WGSS 4999                          Directed Readings
# 3314    WLC 3001     Learning about World Language Learning
# 3315    WLC 3002     Decentering Identities and Borders-CTW
# 3316    WLC 3300    Society in World Literature and Culture
# 3317    WLC 4001                     Global Career Pathways
#
#                                       CourseDescription  \
# 0      Principles of Accounting I3 Credit Hours  Des...
# 1      Principles of Accounting II3 Credit Hours Pre...
# 2      Essentials of Financial Reporting I3 Credit H...
# ...

# %%
gsug_df = pd.read_csv('../data/georgia_grad_final.csv')
gsug_df
# Out:
#      CourseNumber                                        CourseTitle  \
# 0       ACCT 8005                       Current Issues in Accounting
# 1       ACCT 8010                             Financial Accounting 1
# 2       ACCT 8020                            Financial Accounting II
# 3       ACCT 8030      Managerial and Accounting Information Systems
# 4       ACCT 8040                         Topics in Federal Taxation
# ...           ...                                                ...
# 3720     WLC 8320      Cultural and Literary Analysis and Production
# 3721     WLC 8330           The Media, the Arts, and Popular Culture
# 3722     WLC 8340                          Learning a World Language
# 3723     WLC 8350  Identities, Borders, and Social Justice in Lan...
# 3724     WLC 8360  The Profession, Career and Intercultural Exper...
#
#                                       CourseDescription  \
# 0     Current Issues in Accounting1 to 3 Credit Hour...
# ...

# %%
gsug_df['University']= 'GSU'
gsug_df
# Out:
#      CourseNumber                                        CourseTitle  \
# 0       ACCT 8005                       Current Issues in Accounting
# 1       ACCT 8010                             Financial Accounting 1
# 2       ACCT 8020                            Financial Accounting II
# 3       ACCT 8030      Managerial and Accounting Information Systems
# 4       ACCT 8040                         Topics in Federal Taxation
# ...           ...                                                ...
# 3720     WLC 8320      Cultural and Literary Analysis and Production
# 3721     WLC 8330           The Media, the Arts, and Popular Culture
# 3722     WLC 8340                          Learning a World Language
# 3723     WLC 8350  Identities, Borders, and Social Justice in Lan...
# 3724     WLC 8360  The Profession, Career and Intercultural Exper...
#
#                                       CourseDescription  \
# 0     Current Issues in Accounting1 to 3 Credit Hour...
# ...

# %%
gsug_df.to_csv('../data/gsu_g_final.csv', index = None)

# %%
df5 = pd.read_csv('../data/gsu_g_final.csv')
df5
# Out:
#      CourseNumber                                        CourseTitle  \
# 0       ACCT 8005                       Current Issues in Accounting
# 1       ACCT 8010                             Financial Accounting 1
# 2       ACCT 8020                            Financial Accounting II
# 3       ACCT 8030      Managerial and Accounting Information Systems
# 4       ACCT 8040                         Topics in Federal Taxation
# ...           ...                                                ...
# 3720     WLC 8320      Cultural and Literary Analysis and Production
# 3721     WLC 8330           The Media, the Arts, and Popular Culture
# 3722     WLC 8340                          Learning a World Language
# 3723     WLC 8350  Identities, Borders, and Social Justice in Lan...
# 3724     WLC 8360  The Profession, Career and Intercultural Exper...
#
#                                       CourseDescription  \
# 0     Current Issues in Accounting1 to 3 Credit Hour...
# ...

# %%
frames = [df1,df2,df3,df4,df5]
final_df = pd.concat(frames)
final_df.reset_index(inplace = True)
final_df.drop('index', axis=1, inplace = True)
final_df
# Out:
#       CourseNumber                                        CourseTitle  \
# 0       ACCT 5220                                         Income Tax
# 1       ACCT 5311                 Intermediate Financial Reporting I
# 2       ACCT 5312                Intermediate Financial Reporting II
# 3       ACCT 6110                          Tax Research and Planning
# 4       ACCT 6120          Taxation of Corporations and Shareholders
# ...            ...                                                ...
# 27149     WLC 8320      Cultural and Literary Analysis and Production
# 27150     WLC 8330           The Media, the Arts, and Popular Culture
# 27151     WLC 8340                          Learning a World Language
# 27152     WLC 8350  Identities, Borders, and Social Justice in Lan...
# 27153     WLC 8360  The Profession, Career and Intercultural Exper...
#
#                                        CourseDescription  \
# 0      An introduction to the Federal income tax syst...
# ...

# %%
final_df.dtypes
# Out:
# CourseNumber         object
# CourseTitle          object
# CourseDescription    object
# CourseDepartment     object
# University           object
# dtype: object

# %%
final_df.to_csv('../data/combined_final.csv')
